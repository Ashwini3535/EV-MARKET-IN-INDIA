# %% [markdown]
# **FEYNN LABS**
# ---

# %% [markdown]
# **TEAM ARTH**
# ---

# %% [markdown]
# **EV MARKET**
# ----

# %% [markdown]
# ![ev.png](data:image/png;base64,...)

# %% [markdown]
# **What is Electric Vehicle?**
# ---
# An electric vehicle (EV) is an automotive vehicle that uses one or more electric motors for propulsion. It can be powered by a collector system, with electricity from extravehicular sources, or it can be powered autonomously by a battery (sometimes charged by solar panels, or by converting fuel to electricity using fuel cells or a generator).
#
# **Why Electric Vehicle?**
# ---
# The major benefit of electric cars is the contribution that they can make towards improving air quality in towns and cities. With no tailpipe, pure electric cars produce no carbon dioxide emissions when driving. This reduces air pollution considerably.
#
# Put simply, electric cars give us cleaner streets making our towns and cities a better place to be for pedestrians and cyclists. In over a year, just one electric car on the roads can save an average 1.5 million grams of CO2. That’s the equivalent of four return flights from London to Barcelona.
#
# **Main reasons to switch to Electric vehicles:**
# ---
#
# 1.	They are better for the environment.
# 2.	They’re just as safe - if not safer.
# 3.	They are cheaper and easier to maintain.
# 4.	We can receive rebates and tax credits.
# 5.	Upfront costs are falling.
# 6.	We’ll no longer have to pump gas - or spend gas money.
# 7.	More charging stations are popping up.
# 8.	More options are becoming available.
# 9.	Less noise pollution
# 10.	Less maintenance required
# 11.	Government subsidies

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**
# -----

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, classification_report
from sklearn import metrics
# %matplotlib inline

# %% [markdown]
# **Loading the dataset**

# %%
df = pd.read_csv('/content/ev_charger.csv')
print(df, "\n")
# Out:
#               Region     2W     3W    4W  Bus  Chargers
# 0      Uttar Pradesh   9852  42881   458  197       207
# 1         Maharastra  38558    893  1895  186       317
# 2          Karnataka  32844    568   589   57       172
# 3         Tamil Nadu  25642    396   426    0       256
# 4            Gujarat  22359    254   423   22       228
# 5              Delhi  11756   5287  1578  186        72
# 6              Bihar   2388  10783    89   36        37
# 7              Assam    357  11547    42    0        20
# 8             Kerala  10345    308   578    0       131
# 9             Odisha   9540    253    89    0        18
# 10    Andhra Pradesh  14578   2587   524    0       266
# 11         Rajasthan   2387   1578    24    0       205
# 12    Madhya Pradesh   1789   1254    57    0       159
# 13       West Bengal   3547   3654   124    0       141
# 14         Telangana   4578    898   186    0        70
# 15        Chandigadh   1567    542    32    0        70
# ...

# %% [markdown]
# The **head()** returns the first n rows for the object based on position. If your object has the right type of data in it, it is useful for quick testing. This method is used for returning top n (by default value 5) rows of a data frame or series.

# %%
df.head()
# Out:
#           Region     2W     3W    4W  Bus  Chargers
# 0  Uttar Pradesh   9852  42881   458  197       207
# 1     Maharastra  38558    893  1895  186       317
# 2      Karnataka  32844    568   589   57       172
# 3     Tamil Nadu  25642    396   426    0       256
# 4        Gujarat  22359    254   423   22       228

# %% [markdown]
# The **tail()** function displays the last 5 rows of dataframe.

# %%
df.tail()
# Out:
#               Region   2W    3W   4W  Bus  Chargers
# 19   Jammu & Kashmir  187   234   27    0        25
# 20      Chhattisgarh  259   964   34    0        25
# 21       Uttarakhand  954  1865  134    0        10
# 22        Puducherry  641   995   35    0        10
# 23  Himachal Pradesh  824   868  289    0        10

# %% [markdown]
# The **info()** function is used to print a concise summary of a DataFrame. This method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage. Whether to print the full summary.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Region    24 non-null     object
#  1   2W        24 non-null     int64
#  2   3W        24 non-null     int64
#  3   4W        24 non-null     int64
#  4   Bus       24 non-null     int64
#  5   Chargers  24 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# The **shape** function is used o find the shape of the dataframe.It holds the number of rows followed by the number of columns.

# %%
df.shape
# Out:
# (24, 6)

# %% [markdown]
# The **iloc()** function enables us to select a particular cell of the dataset, that is, it helps us select a value that belongs to a particular row or column from a set of values of a data frame or dataset.

# %%
# read csv file from 10th and 15th rows

df.iloc[10:15, :]
# Out:
#             Region     2W    3W   4W  Bus  Chargers
# 10  Andhra Pradesh  14578  2587  524    0       266
# 11       Rajasthan   2387  1578   24    0       205
# 12  Madhya Pradesh   1789  1254   57    0       159
# 13     West Bengal   3547  3654  124    0       141
# 14       Telangana   4578   898  186    0        70

# %% [markdown]
# The **column** function displays all the columns of the dataset.

# %%
df.columns
# Out:
# Index(['Region', '2W', '3W', '4W', 'Bus', 'Chargers'], dtype='object')

# %% [markdown]
# **Detect the missing data**

# %%
print(df.isnull().sum())
# Out:
# Region      0
# 2W          0
# 3W          0
# 4W          0
# Bus         0
# Chargers    0
# dtype: int64

# %% [markdown]
# The **dtype** function describes the type of data.

# %%
df.dtypes
# Out:
# Region      object
# 2W           int64
# 3W           int64
# 4W           int64
# Bus          int64
# Chargers     int64
# dtype: object

# %% [markdown]
# **To check the unique values we use unique function**

# %%
df['Region'].unique()
# Out:
# array(['Uttar Pradesh', 'Maharastra', 'Karnataka', 'Tamil Nadu',
#        'Gujarat', 'Delhi', 'Bihar', 'Assam', 'Kerala', 'Odisha',
#        'Andhra Pradesh', 'Rajasthan', 'Madhya Pradesh', 'West Bengal',
#        'Telangana', 'Chandigadh', 'Haryana', 'Meghalaya', 'Sikkim',
#        'Jammu & Kashmir', 'Chhattisgarh', 'Uttarakhand', 'Puducherry',
#        'Himachal Pradesh'], dtype=object)

# %% [markdown]
# **To check the number of unique values present in our dataset we use nunique function**

# %%
df.Region.nunique()
# Out:
# 24

# %% [markdown]
# The **describe()** method is used for calculating some statistical data like percentile, mean and std of the numerical values of the Series or DataFrame. It analyzes both numeric and object series and also the DataFrame column sets of mixed data types.

# %%
df.describe()
# Out:
#                  2W            3W           4W         Bus    Chargers
# count     24.000000     24.000000    24.000000   24.000000   24.000000
# mean    8421.458333   3853.166667   334.041667   28.500000  107.000000
# std    10942.261145   8850.690961   476.930628   63.771331   96.535193
# min      187.000000    234.000000    12.000000    0.000000   10.000000
# 25%      848.000000    512.750000    34.750000    0.000000   25.000000
# 50%     2967.500000    931.000000   129.000000    0.000000   70.000000
# 75%    10697.750000   2659.250000   434.000000    5.500000  180.250000
# max    38558.000000  42881.000000  1895.000000  197.000000  317.000000

# %% [markdown]
# **DATA VISUALIZATION**
# ----

# %% [markdown]
# **Percentage of total EVs sold whole over India**
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns

labels ='2W', '3W','4W','Bus'
sizes = [8421.458333, 3853.166667,334.041667,28.500000]
colors=['cyan','yellow','pink','black']
fig1, ax1 = plt.subplots()
ax1.pie(sizes,labels=labels, autopct='%1.1f%%',colors=colors, shadow=True, startangle=90)
ax1.axis('equal')

plt.title("Percentage of total number of EVs sold whole over India")

plt.show()

# %% [markdown]
# **Heatmap**
# ---

# %%
# See correlation between variables through a correlation heatmap

corr = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr, annot=True, cmap="cividis")
plt.title('Correlation Heatmap', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# **Number of chargers in particular region**
# ---

# %%
sns.factorplot(x='Chargers', y='Region', data=df)
plt.title("Number of chargers in particular region")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Text(0.5, 1.0, 'Number of chargers in particular region')

# %% [markdown]
# **Chargers in specific region**
# ----

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt


# Creating dataset
Region = ['Uttar Pradesh','Maharastra','Karnataka','Gujarat','Tamil Nadu','Kerala']

data = [207,317,172,228,256,131]


# Creating explode data
explode = (0.1, 0.0, 0.2, 0.3, 0.0, 0.0)

# Creating color parameters
colors = ( "orange", "cyan", "brown",
		"grey", "indigo", "beige")

# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "green" }

# Creating autocpt arguments
def func(pct, allvalues):
	absolute = int(pct / 100.*np.sum(allvalues))
	return "{:.1f}%\n".format(pct, absolute)

# Creating plot
fig, ax = plt.subplots(figsize =(10, 7))
wedges, texts, autotexts = ax.pie(data,
								autopct = lambda pct: func(pct, data),
								explode = explode,
								labels = Region,
								shadow = True,
								colors = colors,
								startangle = 90,
								wedgeprops = wp,
								textprops = dict(color ="black"))

# Adding legend
ax.legend(wedges, Region,
		title ="Regions",
		loc ="center left",
		bbox_to_anchor =(1, 0, 0.5, 1))

plt.setp(autotexts, size = 8, weight ="bold")
ax.set_title("Chargers in specific regions")

# show plot
plt.show()

# %% [markdown]
# **Stacked Bar Plot:**
# ----
# A stacked Bar plot is a kind of bar graph in which each bar is visually divided into sub bars to represent multiple column data at once. To plot the Stacked Bar plot we need to specify stacked=True in the plot method. We can also pass the list of colors as we needed to color each sub bar in a bar.

# %% [markdown]
# **Total number of Two wheelers,Three wheelers and Four wheelers sold in specific regions.**
# ----

# %%
# import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# create DataFrame
df = pd.DataFrame({'2W': [9852,38558,32844,25642,22359,11756,2388,357,10345],
				'3W': [42881,893,568,396,254,5287,10783,11547,308],
				'4W': [458,1895,589,426,423,1578,89,42,578]},
				index=['Uttar Pradesh','Maharastra','Karnataka','Tamil Nadu','Gujarat','Delhi','Bihar','Assam','Kerala'])


# create stacked bar chart for monthly temperatures
df.plot(kind='bar', stacked=True, color=['red', 'skyblue', 'green'])

# labels for x & y axis
plt.xlabel('Regions')
plt.ylabel('Number of EVs')

# title of plot
plt.title('Total number of Two wheelers,Three wheelers and Four wheelers sold in specific regions')
# Out:
# Text(0.5, 1.0, 'Total number of Two wheelers,Three wheelers and Four wheelers sold in specific regions')

# %% [markdown]
# **Most types of EV vehicles sold whole over India**
# -----

# %%
# importing modules 
import matplotlib.pyplot as plt
import numpy as np
  
# assigning x and y coordinates
average = ['2W','3W','4W','Bus']
types = [8421.458333, 3853.166667,334.041667,28.500000]
  
# depicting the visualization
index = np.arange(len(average))
plt.bar(index, types, color='red')
plt.xlabel('Types')
plt.ylabel('Average')
plt.xticks(index, average)
  
# displaying the title
plt.title(label='Types of EV vehicles sold whole over India', 
          fontweight=20, 
          pad='2.0')
# Out:
# Text(0.5, 1.0, 'Types of EV vehicles sold whole over India')

# %% [markdown]
# **EVs sold in Maharashtra**
# ---

# %%
# importing modules 
import matplotlib.pyplot as plt
import numpy as np
  
# assigning x and y coordinates
average = ['2W','3W','4W','Bus']
types = [38558,893,1895,186]
  
# depicting the visualization
index = np.arange(len(average))
plt.bar(index, types, color='purple')
plt.xlabel('Types')
plt.ylabel('Average')
plt.xticks(index, average)
  
# displaying the title
plt.title(label='EVs sold in Maharashtra', 
          fontweight=20, 
          pad='2.0')
# Out:
# Text(0.5, 1.0, 'EVs sold in Maharashtra')
